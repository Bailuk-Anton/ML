# %%
# 2 Лабораторная работа

# Цель - познакомиться с методом кластеризации K-mean с помощью пакета sklearn. 

# Для выполнения задания используется набор данных из предыдущей лр.
# Что нужно сделать:
# 1. К текущему датасету необходимо добавить новый аттрибут, например, если есть дата рождения, 
# то посчитать возраст или определить популярность фильма по количеству просмотров и т.п.
# 2. "Причесать" датасет: удалить выбросы и дубли, обработать пропущенные значения, найти кривые данные и т.п.
# 3. Построить графики зависимости одной переменной от другой (plt.scatter), описать какие кластеры (группы) 
# вы видите. Построить несколько разных графиков, найти ярковыраженные группы.
# 4. Изучить перечисленные ноутбуки, по примеру, попробовать применить метод KMeans к вашему датасету 
# (https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)
# https://www.kaggle.com/kushal1996/customer-segmentation-k-means-analysis
# https://www.kaggle.com/karthickaravindan/k-means-clustering-project
# https://www.kaggle.com/hellbuoy/online-retail-k-means-hierarchical-clustering
# https://www.kaggle.com/sirpunch/k-means-clustering
# Если ваш датасет не подходит для задачи, его можно поменять. 

# 5. Написать выводы
# Если не установлен sklearn - https://scikit-learn.org/stable/install.html

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

df = pd.read_csv("../data/Sleep_health_and_lifestyle_dataset.csv")

# %%
df[['Systolic', 'Diastolic']] = df['Blood Pressure'].str.split('/', expand=True).astype(int)
df = df.fillna('None')

# %%
numeric_cols = [
    'Age',
    'Sleep Duration',
    'Quality of Sleep',
    'Physical Activity Level',
    'Stress Level',
    'Heart Rate',
    'Daily Steps',
    'Systolic',
    'Diastolic'
]

categorical_cols = [
    'Gender',
    'Occupation',
    'BMI Category',
    'Sleep Disorder'
]

# %%
# 2.1. К текущему датасету необходимо добавить новый аттрибут, например, если есть дата рождения, 
# то посчитать возраст или определить популярность фильма по количеству просмотров и т.п.

# Новый признак: чем выше — тем хуже баланс между стрессом и сном
df['Sleep_Stress_Index'] = df['Stress Level'] / df['Quality of Sleep']

# %%
# 2.2. "Причесать" датасет: удалить выбросы и дубли, обработать пропущенные значения, найти кривые данные и т.п.

def remove_outliers_iqr(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return df[(df[col] >= lower) & (df[col] <= upper)]

# Применим последовательно
for col in numeric_cols:
    df = remove_outliers_iqr(df, col)

# %%
# 2.3. Построить графики зависимости одной переменной от другой (plt.scatter), описать какие кластеры (группы) 
# вы видите. Построить несколько разных графиков, найти ярковыраженные группы.

plt.figure(figsize=(14, 5))

# График 1: Стресс vs Качество сна
plt.subplot(1, 2, 1)
plt.scatter(df['Stress Level'], df['Quality of Sleep'], alpha=0.6)
plt.xlabel('Stress Level')
plt.ylabel('Quality of Sleep')
plt.title('Стресс vs Качество сна')

# График 2: Физическая активность vs Продолжительность сна
plt.subplot(1, 2, 2)
plt.scatter(df['Physical Activity Level'], df['Sleep Duration'], alpha=0.6, color='green')
plt.xlabel('Physical Activity (min/day)')
plt.ylabel('Sleep Duration (hours)')
plt.title('Активность vs Длительность сна')

plt.tight_layout()
plt.show()

# %%
# 2.4. Изучить перечисленные ноутбуки, по примеру, попробовать применить метод KMeans к вашему датасету 
# (https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)
X = df[numeric_cols]

# Стандартизация KMeans
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.metrics import silhouette_score

inertias = []
silhouettes = []
K_range = range(2, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init="auto")
    kmeans.fit(X_scaled)
    inertias.append(kmeans.inertia_)
    silhouettes.append(silhouette_score(X_scaled, kmeans.labels_))

# График инерции (локоть)
plt.figure(figsize=(12, 4))

plt.plot(K_range, inertias, 'bo-')
plt.xlabel('k')
plt.ylabel('Inertia')


plt.tight_layout()
plt.show()

# %%
X1 = df[['Stress Level', 'Quality of Sleep']].values

# Кластеризация
algorithm = KMeans(n_clusters=4, init='k-means++', n_init=10, max_iter=300,
                   tol=0.0001, random_state=111, algorithm='elkan')
algorithm.fit(X1)
labels1 = algorithm.labels_
centroids1 = algorithm.cluster_centers_

# Границы для сетки
h = 0.02
x_min, x_max = X1[:, 0].min() - 1, X1[:, 0].max() + 1
y_min, y_max = X1[:, 1].min() - 1, X1[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = algorithm.predict(np.c_[xx.ravel(), yy.ravel()])

# Построение графика
plt.figure(1, figsize=(15, 7))
plt.clf()
Z = Z.reshape(xx.shape)
plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap=plt.cm.Pastel2, aspect='auto', origin='lower')

plt.scatter(x='Stress Level', y='Quality of Sleep', data=df, c=labels1, s=200)
plt.scatter(x=centroids1[:, 0], y=centroids1[:, 1], s=300, c='red', alpha=0.5)
plt.ylabel('Quality of Sleep')
plt.xlabel('Stress Level')
plt.title('K-Means Clustering (Stress Level vs Quality of Sleep)')
plt.show()

# 1. Количество объектов в каждом кластере
cluster_counts = Counter(labels1)
print("\nКоличество объектов в каждом кластере:")
for cluster_id in sorted(cluster_counts):
    print(f"Кластер {cluster_id}: {cluster_counts[cluster_id]} объектов")

# 2. Средние значения признаков по кластерам
df_with_labels = df[['Stress Level', 'Quality of Sleep']].copy()
df_with_labels['Cluster'] = labels1

cluster_means = df_with_labels.groupby('Cluster').mean()
print("\nСредние значения по кластерам:")
print(cluster_means)

# 3. Координаты центроидов (уже есть в centroids1)
print("\nКоординаты центроидов:")
for i, centroid in enumerate(centroids1):
    print(f"Кластер {i}: Stress Level = {centroid[0]:.2f}, Quality of Sleep = {centroid[1]:.2f}")
# Out:
# Количество объектов в каждом кластере:
# Кластер 0: 71 объектов
# Кластер 1: 104 объектов
# Кластер 2: 131 объектов
# Кластер 3: 53 объектов
#
# Средние значения по кластерам:
#          Stress Level  Quality of Sleep
# Cluster
# 0            3.028169          8.971831
# 1            7.625000          5.961538
# 2            4.480916          7.786260
# 3            6.132075          7.000000
#
# Координаты центроидов:
# Кластер 0: Stress Level = 3.03, Quality of Sleep = 8.97
# Кластер 1: Stress Level = 7.62, Quality of Sleep = 5.96
# Кластер 2: Stress Level = 4.48, Quality of Sleep = 7.79
# Кластер 3: Stress Level = 6.13, Quality of Sleep = 7.00

# %%
X1 = df[['Stress Level', 'Quality of Sleep']].values

# Кластеризация
algorithm = KMeans(n_clusters=8, init='k-means++', n_init=10, max_iter=300,
                   tol=0.0001, random_state=111, algorithm='elkan')
algorithm.fit(X1)
labels1 = algorithm.labels_
centroids1 = algorithm.cluster_centers_

# Границы для сетки
h = 0.02
x_min, x_max = X1[:, 0].min() - 1, X1[:, 0].max() + 1
y_min, y_max = X1[:, 1].min() - 1, X1[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = algorithm.predict(np.c_[xx.ravel(), yy.ravel()])

# Построение графика
plt.figure(1, figsize=(15, 7))
plt.clf()
Z = Z.reshape(xx.shape)
plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap=plt.cm.Pastel2, aspect='auto', origin='lower')

plt.scatter(x='Stress Level', y='Quality of Sleep', data=df, c=labels1, s=200)
plt.scatter(x=centroids1[:, 0], y=centroids1[:, 1], s=300, c='red', alpha=0.5)
plt.ylabel('Quality of Sleep')
plt.xlabel('Stress Level')
plt.title('K-Means Clustering (Stress Level vs Quality of Sleep)')
plt.show()

# 1. Количество объектов в каждом кластере
cluster_counts = Counter(labels1)
print("\nКоличество объектов в каждом кластере:")
for cluster_id in sorted(cluster_counts):
    print(f"Кластер {cluster_id}: {cluster_counts[cluster_id]} объектов")

# 2. Средние значения признаков по кластерам
df_with_labels = df[['Stress Level', 'Quality of Sleep']].copy()
df_with_labels['Cluster'] = labels1

cluster_means = df_with_labels.groupby('Cluster').mean()
print("\nСредние значения по кластерам:")
print(cluster_means)

# 3. Координаты центроидов (уже есть в centroids1)
print("\nКоординаты центроидов:")
for i, centroid in enumerate(centroids1):
    print(f"Кластер {i}: Stress Level = {centroid[0]:.2f}, Quality of Sleep = {centroid[1]:.2f}")
# Out:
# Количество объектов в каждом кластере:
# Кластер 0: 28 объектов
# Кластер 1: 43 объектов
# Кластер 2: 64 объектов
# Кластер 3: 71 объектов
# Кластер 4: 38 объектов
# Кластер 5: 65 объектов
# Кластер 6: 43 объектов
# Кластер 7: 7 объектов
#
# Средние значения по кластерам:
#          Stress Level  Quality of Sleep
# Cluster
# 0            4.107143          7.000000
# 1            6.906977          5.906977
# 2            5.062500          8.000000
# 3            3.028169          8.971831
# 4            6.000000          7.000000
# 5            8.000000          6.000000
# 6            4.000000          8.000000
# 7            7.000000          7.000000
#
# Координаты центроидов:
# Кластер 0: Stress Level = 4.11, Quality of Sleep = 7.00
# Кластер 1: Stress Level = 6.91, Quality of Sleep = 5.91
# Кластер 2: Stress Level = 5.06, Quality of Sleep = 8.00
# Кластер 3: Stress Level = 3.03, Quality of Sleep = 8.97
# Кластер 4: Stress Level = 6.00, Quality of Sleep = 7.00
# ...

# %%
X1 = df[['Physical Activity Level' , 'Sleep Duration']].values

# Кластеризация
algorithm = KMeans(n_clusters=4, init='k-means++', n_init=10, max_iter=300,
                   tol=0.0001, random_state=111, algorithm='elkan')
algorithm.fit(X1)
labels1 = algorithm.labels_
centroids1 = algorithm.cluster_centers_

# Границы для сетки
h = 0.02
x_min, x_max = X1[:, 0].min() - 1, X1[:, 0].max() + 1
y_min, y_max = X1[:, 1].min() - 1, X1[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = algorithm.predict(np.c_[xx.ravel(), yy.ravel()])

# Построение графика
plt.figure(1, figsize=(15, 7))
plt.clf()
Z = Z.reshape(xx.shape)
plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap=plt.cm.Pastel2, aspect='auto', origin='lower')

plt.scatter(x='Physical Activity Level', y='Quality of Sleep', data=df, c=labels1, s=200)
plt.scatter(x=centroids1[:, 0], y=centroids1[:, 1], s=300, c='red', alpha=0.5)
plt.ylabel('Sleep Duration')
plt.xlabel('Physical Activity Level')
plt.title('K-Means Clustering (Stress Level vs Quality of Sleep)')
plt.show()

# 1. Количество объектов в каждом кластере
cluster_counts = Counter(labels1)
print("\nКоличество объектов в каждом кластере:")
for cluster_id in sorted(cluster_counts):
    print(f"Кластер {cluster_id}: {cluster_counts[cluster_id]} объектов")

# 2. Средние значения признаков по кластерам
df_with_labels = df[['Physical Activity Level', 'Sleep Duration']].copy()
df_with_labels['Cluster'] = labels1

cluster_means = df_with_labels.groupby('Cluster').mean()
print("\nСредние значения по кластерам:")
print(cluster_means)

# 3. Координаты центроидов (уже есть в centroids1)
print("\nКоординаты центроидов:")
for i, centroid in enumerate(centroids1):
    print(f"Кластер {i}: Stress Level = {centroid[0]:.2f}, Quality of Sleep = {centroid[1]:.2f}")
# Out:
# Количество объектов в каждом кластере:
# Кластер 0: 142 объектов
# Кластер 1: 67 объектов
# Кластер 2: 72 объектов
# Кластер 3: 78 объектов
#
# Средние значения по кластерам:
#          Physical Activity Level  Sleep Duration
# Cluster
# 0                      37.753521        6.856338
# 1                      90.000000        6.959701
# 2                      74.930556        7.904167
# 3                      59.102564        7.150000
#
# Координаты центроидов:
# Кластер 0: Stress Level = 37.75, Quality of Sleep = 6.86
# Кластер 1: Stress Level = 90.00, Quality of Sleep = 6.96
# Кластер 2: Stress Level = 74.93, Quality of Sleep = 7.90
# Кластер 3: Stress Level = 59.10, Quality of Sleep = 7.15

# %%
X1 = df[['Physical Activity Level' , 'Sleep Duration']].values

# Кластеризация
algorithm = KMeans(n_clusters=8, init='k-means++', n_init=10, max_iter=300,
                   tol=0.0001, random_state=111, algorithm='elkan')
algorithm.fit(X1)
labels1 = algorithm.labels_
centroids1 = algorithm.cluster_centers_

# Границы для сетки
h = 0.02
x_min, x_max = X1[:, 0].min() - 1, X1[:, 0].max() + 1
y_min, y_max = X1[:, 1].min() - 1, X1[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = algorithm.predict(np.c_[xx.ravel(), yy.ravel()])

# Построение графика
plt.figure(1, figsize=(15, 7))
plt.clf()
Z = Z.reshape(xx.shape)
plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap=plt.cm.Pastel2, aspect='auto', origin='lower')

plt.scatter(x='Physical Activity Level', y='Quality of Sleep', data=df, c=labels1, s=200)
plt.scatter(x=centroids1[:, 0], y=centroids1[:, 1], s=300, c='red', alpha=0.5)
plt.ylabel('Sleep Duration')
plt.xlabel('Physical Activity Level')
plt.title('K-Means Clustering (Stress Level vs Quality of Sleep)')
plt.show()


# 1. Количество объектов в каждом кластере
cluster_counts = Counter(labels1)
print("\nКоличество объектов в каждом кластере:")
for cluster_id in sorted(cluster_counts):
    print(f"Кластер {cluster_id}: {cluster_counts[cluster_id]} объектов")

# 2. Средние значения признаков по кластерам
df_with_labels = df[['Physical Activity Level', 'Sleep Duration']].copy()
df_with_labels['Cluster'] = labels1

cluster_means = df_with_labels.groupby('Cluster').mean()
print("\nСредние значения по кластерам:")
print(cluster_means)

# 3. Координаты центроидов
print("\nКоординаты центроидов:")
for i, centroid in enumerate(centroids1):
    print(f"Кластер {i}: Stress Level = {centroid[0]:.2f}, Quality of Sleep = {centroid[1]:.2f}")
# Out:
# Количество объектов в каждом кластере:
# Кластер 0: 33 объектов
# Кластер 1: 68 объектов
# Кластер 2: 67 объектов
# Кластер 3: 71 объектов
# Кластер 4: 72 объектов
# Кластер 5: 32 объектов
# Кластер 6: 6 объектов
# Кластер 7: 10 объектов
#
# Средние значения по кластерам:
#          Physical Activity Level  Sleep Duration
# Cluster
# 0                      30.000000        6.100000
# 1                      60.000000        7.185294
# 2                      90.000000        6.959701
# 3                      44.943662        6.525352
# 4                      74.930556        7.904167
# 5                      30.000000        8.425000
# 6                      36.666667        6.566667
# 7                      53.000000        6.910000
#
# Координаты центроидов:
# Кластер 0: Stress Level = 30.00, Quality of Sleep = 6.10
# Кластер 1: Stress Level = 60.00, Quality of Sleep = 7.19
# Кластер 2: Stress Level = 90.00, Quality of Sleep = 6.96
# ...

# %%
# Вывод: 
# В ходе данной работы была произведена кластерезация датасета по параметрам:
# ['Physical Activity Level' , 'Sleep Duration']
# ['Stress Level', 'Quality of Sleep']

# Благодаря работе с кластерами возможно распределение элементов по признакам. 
# Группировка элементов очень помогает в таргетировании поставленных целей и, в следствии, 
# экономии ресурсов затраченных на работу, лечение и профилактику.
